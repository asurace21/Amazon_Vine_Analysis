# %%
import pandas as pd

# %%
vine_df = pd.read_csv("vine_table.csv")
vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0       R27ZP1F1CD0C3Y            5              0            0    N
# 1        RJ7RSBCHUDNNE            5              0            0    N
# 2       R1HVYBSKLQJI5S            5              0            0    N
# 3       R2HAXF0IIYQBIR            1              0            0    N
# 4        RNYLPX611NB7Q            5              0            0    N
# ...                ...          ...            ...          ...  ...
# 149081   R57O26VBSLMP1            5             10           10    N
# 149082  R375D634NGSSPI            4              8           44    N
# 149083  R2NCVKVC9B7I9C            5             20           30    N
# 149084   RC2BIM4XKDCY4            4             63           72    N
# 149085   RKOEI5NT6A7LL            5             26           29    N
#
#         verified_purchase
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 149081                NaN
# 149082                NaN
# 149083                NaN
# 149084                NaN
# 149085                NaN
#
# [149086 rows x 6 columns]

# %%
df1 = vine_df.loc[vine_df["total_votes"] >= 20]
df1
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 685     R36PQ9D8L2AAOH            5             30           32    N
# 1786    R23GHBE86II0SK            5             18           21    N
# 2020    R18KVPY0TO33BM            5            241          248    N
# 2429    R2ZB78BDM8BRCF            1             99          113    N
# 4971    R2JMJOWGM7V7NX            4             20           20    N
# ...                ...          ...            ...          ...  ...
# 149078  R24VDTJFJEPNYB            1             10           32    N
# 149082  R375D634NGSSPI            4              8           44    N
# 149083  R2NCVKVC9B7I9C            5             20           30    N
# 149084   RC2BIM4XKDCY4            4             63           72    N
# 149085   RKOEI5NT6A7LL            5             26           29    N
#
#         verified_purchase
# 685                   NaN
# 1786                  NaN
# 2020                  NaN
# 2429                  NaN
# 4971                  NaN
# ...                   ...
# 149078                NaN
# 149082                NaN
# 149083                NaN
# 149084                NaN
# 149085                NaN
#
# [392 rows x 6 columns]

# %%
df2 = df1.loc[(df1["helpful_votes"]/df1["total_votes"] >= 0.5)]
df2
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 685     R36PQ9D8L2AAOH            5             30           32    N
# 1786    R23GHBE86II0SK            5             18           21    N
# 2020    R18KVPY0TO33BM            5            241          248    N
# 2429    R2ZB78BDM8BRCF            1             99          113    N
# 4971    R2JMJOWGM7V7NX            4             20           20    N
# ...                ...          ...            ...          ...  ...
# 149071   RTL2UNB1DE5YH            5             21           22    N
# 149077   RGPOFKORD8RTU            5            105          107    N
# 149083  R2NCVKVC9B7I9C            5             20           30    N
# 149084   RC2BIM4XKDCY4            4             63           72    N
# 149085   RKOEI5NT6A7LL            5             26           29    N
#
#         verified_purchase
# 685                   NaN
# 1786                  NaN
# 2020                  NaN
# 2429                  NaN
# 4971                  NaN
# ...                   ...
# 149071                NaN
# 149077                NaN
# 149083                NaN
# 149084                NaN
# 149085                NaN
#
# [355 rows x 6 columns]

# %%
df2["vine"].value_counts()
# Out:
# N    355
# Name: vine, dtype: int64

# %%
paid_df = df2.loc[df2["vine"]=="Y"]
paid_df
# Out:
# Empty DataFrame
# Columns: [review_id, star_rating, helpful_votes, total_votes, vine, verified_purchase]
# Index: []

# %%
unpaid_df = df2.loc[df2["vine"]=="N"]
unpaid_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 685     R36PQ9D8L2AAOH            5             30           32    N
# 1786    R23GHBE86II0SK            5             18           21    N
# 2020    R18KVPY0TO33BM            5            241          248    N
# 2429    R2ZB78BDM8BRCF            1             99          113    N
# 4971    R2JMJOWGM7V7NX            4             20           20    N
# ...                ...          ...            ...          ...  ...
# 149071   RTL2UNB1DE5YH            5             21           22    N
# 149077   RGPOFKORD8RTU            5            105          107    N
# 149083  R2NCVKVC9B7I9C            5             20           30    N
# 149084   RC2BIM4XKDCY4            4             63           72    N
# 149085   RKOEI5NT6A7LL            5             26           29    N
#
#         verified_purchase
# 685                   NaN
# 1786                  NaN
# 2020                  NaN
# 2429                  NaN
# 4971                  NaN
# ...                   ...
# 149071                NaN
# 149077                NaN
# 149083                NaN
# 149084                NaN
# 149085                NaN
#
# [355 rows x 6 columns]

# %%
paid_five_star_number = paid_df.loc[(paid_df['star_rating']== 5)]["star_rating"].count()
paid_five_star_number
# Out:
# 0

# %%
paid_five_star_number = paid_df.loc[(paid_df['star_rating']== 5)]["star_rating"].count()


paid_number = paid_df["star_rating"].count()


percentage_five_star_vine = paid_five_star_number / paid_number * 100


print(f"5 Star Rating: {paid_five_star_number}")
print(f"Total Rating: {paid_number}")
print(f"Percentage of 5 star: {round(percentage_five_star_vine,2)}%")
# Out:
# 5 Star Rating: 0
# Total Rating: 0
# Percentage of 5 star: nan%
# C:\Users\Andrew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in longlong_scalars
#   import sys

# %%
unpaid_five_star_number = unpaid_df.loc[(unpaid_df['star_rating']== 5)]["star_rating"].count()


unpaid_number = unpaid_df["star_rating"].count()


percentage_five_star_non_vine = unpaid_five_star_number / unpaid_number * 100



print(f"Total Rating: {unpaid_five_star_number}")
print(f"Percentage of 5 star: {round(percentage_five_star_non_vine,2)}%")
# Out:
# Total Rating: 90
# Percentage of 5 star: 25.35%
